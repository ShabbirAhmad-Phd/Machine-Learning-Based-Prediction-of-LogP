# %%
import matplotlib.pyplot as plt

# Sample alpha values (log scale)
alphas = [0.001, 0.01, 0.1, 1, 10, 100, 1000]

# Mock performance metrics (you can replace these with actual values)
lasso_rmse = [2.5, 2.3, 2.1, 2.05, 2.2, 2.6, 2.8]
lasso_r2 = [0.2, 0.4, 0.65, 0.72, 0.55, 0.3, 0.1]

enet_rmse = [2.4, 2.2, 2.15, 2.1, 2.25, 2.5, 2.7]
enet_r2 = [0.25, 0.45, 0.6, 0.68, 0.52, 0.35, 0.15]

ridge_rmse = [2.6, 2.4, 2.2, 2.0, 2.1, 2.3, 2.5]
ridge_r2 = [0.15, 0.35, 0.55, 0.7, 0.6, 0.4, 0.2]

# Find optimal alpha indices
optimal_indices = {
    "Lasso": lasso_rmse.index(min(lasso_rmse)),
    "ElasticNet": enet_rmse.index(min(enet_rmse)),
    "Ridge": ridge_rmse.index(min(ridge_rmse))
}

# Plotting
fig, axs = plt.subplots(2, 3, figsize=(15, 8), sharex=True)

def highlight_point(ax, alpha, value):
    ax.scatter(alpha, value, color='black', marker='*', s=150, zorder=5)
    ax.annotate(f'α={alpha}', (alpha, value), textcoords="offset points", xytext=(0, -20),
                ha='center', fontsize=9)

# Top row: RMSE
axs[0, 0].plot(alphas, lasso_rmse, marker='o', color='tomato')
highlight_point(axs[0, 0], alphas[optimal_indices["Lasso"]], lasso_rmse[optimal_indices["Lasso"]])
axs[0, 0].set_title('Lasso - RMSE')
axs[0, 0].set_ylabel('RMSE')
axs[0, 0].set_xscale('log')

axs[0, 1].plot(alphas, enet_rmse, marker='o', color='tomato')
highlight_point(axs[0, 1], alphas[optimal_indices["ElasticNet"]], enet_rmse[optimal_indices["ElasticNet"]])
axs[0, 1].set_title('ElasticNet - RMSE')
axs[0, 1].set_xscale('log')

axs[0, 2].plot(alphas, ridge_rmse, marker='o', color='tomato')
highlight_point(axs[0, 2], alphas[optimal_indices["Ridge"]], ridge_rmse[optimal_indices["Ridge"]])
axs[0, 2].set_title('Ridge - RMSE')
axs[0, 2].set_xscale('log')

# Bottom row: R²
axs[1, 0].plot(alphas, lasso_r2, marker='o', color='teal')
highlight_point(axs[1, 0], alphas[optimal_indices["Lasso"]], lasso_r2[optimal_indices["Lasso"]])
axs[1, 0].set_title('Lasso - R²')
axs[1, 0].set_xlabel('Alpha')
axs[1, 0].set_ylabel('R²')
axs[1, 0].set_xscale('log')

axs[1, 1].plot(alphas, enet_r2, marker='o', color='teal')
highlight_point(axs[1, 1], alphas[optimal_indices["ElasticNet"]], enet_r2[optimal_indices["ElasticNet"]])
axs[1, 1].set_title('ElasticNet - R²')
axs[1, 1].set_xlabel('Alpha')
axs[1, 1].set_xscale('log')

axs[1, 2].plot(alphas, ridge_r2, marker='o', color='teal')
highlight_point(axs[1, 2], alphas[optimal_indices["Ridge"]], ridge_r2[optimal_indices["Ridge"]])
axs[1, 2].set_title('Ridge - R²')
axs[1, 2].set_xlabel('Alpha')
axs[1, 2].set_xscale('log')

fig.suptitle('Figure 10. RMSE (Top) and R² (Bottom) vs. Alpha for Lasso, ElasticNet, and Ridge\n(Optimal Alpha Values Highlighted)', fontsize=14)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Save
plt.savefig("Figure_10_Optimal_Alpha_Highlighted.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Alpha values (log scale)
alphas = [0.001, 0.01, 0.1, 1, 10, 100, 1000]


# Mock model performance metrics
lasso_rmse = [2.5, 2.3, 2.1, 2.05, 2.2, 2.6, 2.8]
lasso_r2 = [0.2, 0.4, 0.65, 0.72, 0.55, 0.3, 0.1]

enet_rmse = [2.4, 2.2, 2.15, 2.1, 2.25, 2.5, 2.7]
enet_r2 = [0.25, 0.45, 0.6, 0.68, 0.52, 0.35, 0.15]

ridge_rmse = [2.6, 2.4, 2.2, 2.0, 2.1, 2.3, 2.5]
ridge_r2 = [0.15, 0.35, 0.55, 0.7, 0.6, 0.4, 0.2]

# 🧪 Manually define known optimal alpha values
optimal_alphas["Lasso"] = 0.070
optimal_alphas["ElasticNet"] = 0.100
optimal_alphas["Ridge"] = 0.100


# Find the closest index in alphas list to each optimal alpha
def find_closest_index(alpha_list, target):
    return min(range(len(alpha_list)), key=lambda i: abs(alpha_list[i] - target))

optimal_indices = {
    "Lasso": find_closest_index(alphas, optimal_alphas["Lasso"]),
    "ElasticNet": find_closest_index(alphas, optimal_alphas["ElasticNet"]),
    "Ridge": find_closest_index(alphas, optimal_alphas["Ridge"])
}

# Plotting
fig, axs = plt.subplots(2, 3, figsize=(15, 8), sharex=True)

def highlight_point(ax, alpha, value):
    ax.scatter(alpha, value, color='black', marker='*', s=150, zorder=5)
    ax.annotate(f'α = {alpha:.2f}', (alpha, value), textcoords="offset points",
                xytext=(0, -20), ha='center', fontsize=9)

# Top row: RMSE
axs[0, 0].plot(alphas, lasso_rmse, marker='o', color='tomato')
highlight_point(axs[0, 0], optimal_alphas["Lasso"], lasso_rmse[optimal_indices["Lasso"]])
axs[0, 0].set_title('Lasso - RMSE')
axs[0, 0].set_ylabel('RMSE')
axs[0, 0].set_xscale('log')

axs[0, 1].plot(alphas, enet_rmse, marker='o', color='tomato')
highlight_point(axs[0, 1], optimal_alphas["ElasticNet"], enet_rmse[optimal_indices["ElasticNet"]])
axs[0, 1].set_title('ElasticNet - RMSE')
axs[0, 1].set_xscale('log')

axs[0, 2].plot(alphas, ridge_rmse, marker='o', color='tomato')
highlight_point(axs[0, 2], optimal_alphas["Ridge"], ridge_rmse[optimal_indices["Ridge"]])
axs[0, 2].set_title('Ridge - RMSE')
axs[0, 2].set_xscale('log')

# Bottom row: R²
axs[1, 0].plot(alphas, lasso_r2, marker='o', color='teal')
highlight_point(axs[1, 0], optimal_alphas["Lasso"], lasso_r2[optimal_indices["Lasso"]])
axs[1, 0].set_title('Lasso - R²')
axs[1, 0].set_xlabel('Alpha')
axs[1, 0].set_ylabel('R²')
axs[1, 0].set_xscale('log')

axs[1, 1].plot(alphas, enet_r2, marker='o', color='teal')
highlight_point(axs[1, 1], optimal_alphas["ElasticNet"], enet_r2[optimal_indices["ElasticNet"]])
axs[1, 1].set_title('ElasticNet - R²')
axs[1, 1].set_xlabel('Alpha')
axs[1, 1].set_xscale('log')

axs[1, 2].plot(alphas, ridge_r2, marker='o', color='teal')
highlight_point(axs[1, 2], optimal_alphas["Ridge"], ridge_r2[optimal_indices["Ridge"]])
axs[1, 2].set_title('Ridge - R²')
axs[1, 2].set_xlabel('Alpha')
axs[1, 2].set_xscale('log')

fig.suptitle('Figure 10. RMSE (Top) and R² (Bottom) vs. Alpha for Lasso, ElasticNet, and Ridge\n(Optimal Alpha Values Highlighted)', fontsize=14)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.savefig("Figure_10_Manual_Optimal_Alpha.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Example compound list (replace with your actual compound names if needed)
compounds = [
    'Belzutifan', 'Carmustine', 'Eletriptan', 'Captopril',
    'Rizatriptan', 'Sumatriptan', 'Telmisartan', 'Zolmitriptan',
    'Dabrafenib', 'Metronidazole', 'Theobromine', 'Almotriptan'
]

# Simulated SHAP values for PC1 and PC2 (replace with your actual values)
np.random.seed(42)
shap_df = pd.DataFrame({
    'Compound': compounds,
    'PC1': np.random.normal(loc=0.5, scale=0.15, size=12),
    'PC2': np.random.normal(loc=-0.3, scale=0.1, size=12)
})

# Reshape to long format for seaborn
shap_long = pd.melt(shap_df, id_vars='Compound', var_name='Feature', value_name='SHAP Value')

# Beeswarm-style strip plot with cross markers
plt.figure(figsize=(10, 6))
sns.stripplot(
    data=shap_long,
    x='Feature', y='SHAP Value',
    hue='Compound',
    jitter=0.25, dodge=True,
    palette='tab10',
    marker='x', size=9, linewidth=1.2
)

# Add plot formatting
plt.axhline(0, color='gray', linestyle='--', linewidth=1)
plt.title('Figure X. SHAP Values for PC1 and PC2 Across 12 Compounds (× Marker)')
plt.xlabel('PCA Feature')
plt.ylabel('SHAP Value (Impact on LogP Prediction)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Compound')
plt.tight_layout()

# Save the figure
plt.savefig("Figure_X_SHAP_Beeswarm_Cross_Marked.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# ✅ Simulated cross-validation residuals (5 folds × 12 predictions = 60 total)
np.random.seed(42)
residuals = np.random.normal(loc=0, scale=1.5, size=60)  # Replace with actual residuals if available
folds = np.repeat(np.arange(1, 6), 12)  # 5 CV folds

# ✅ Plot
plt.figure(figsize=(10, 6))
plt.scatter(folds, residuals, color='darkorange', edgecolor='black', s=60, alpha=0.8)

# Reference line at residual = 0
plt.axhline(0, color='gray', linestyle='--', linewidth=1)

# Labels and title
plt.title('Figure 16. Cross-Validated Residuals Across 5 Folds', fontsize=14)
plt.xlabel('Cross-Validation Fold')
plt.ylabel('Residual (Predicted − Actual LogP)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# Save the figure
plt.savefig("Figure_16_CrossValidated_Residuals.png", dpi=300)
plt.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 🔢 Replace this with your actual topological index dataset (12 compounds × 8 features)
# Example dummy dataframe:
topological_data = pd.DataFrame({
    'R1': [2.1, 3.2, 2.8, 3.0, 2.9, 3.3, 3.1, 2.7, 3.4, 3.0, 2.5, 2.6],
    'R2': [1.5, 2.1, 1.9, 2.0, 2.3, 2.2, 2.4, 1.8, 2.5, 2.0, 1.7, 1.6],
    'R3': [4.2, 4.8, 4.5, 4.6, 4.3, 4.9, 4.7, 4.4, 5.0, 4.6, 4.1, 4.0],
    'R4': [0.9, 1.2, 1.0, 1.1, 1.3, 1.4, 1.2, 1.1, 1.5, 1.3, 1.0, 0.8],
    'R5': [1.7, 2.0, 1.8, 1.9, 2.1, 2.2, 2.0, 1.8, 2.3, 2.1, 1.6, 1.5],
    'R6': [0.6, 0.7, 0.65, 0.66, 0.68, 0.7, 0.69, 0.64, 0.72, 0.71, 0.6, 0.59],
    'GQ': [3.5, 3.8, 3.6, 3.7, 3.9, 4.0, 3.9, 3.6, 4.1, 4.0, 3.4, 3.3],
    'QG': [2.9, 3.0, 3.1, 3.2, 3.4, 3.5, 3.3, 3.1, 3.6, 3.5, 2.8, 2.7]
})

# 🧪 Step 1: Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(topological_data)

# 🧠 Step 2: Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# 📊 Step 3: Create loadings table
loadings = pd.DataFrame(
    pca.components_.T,
    columns=['PC1', 'PC2'],
    index=topological_data.columns
)

# 📈 Step 4: Explained variance
explained_var = pca.explained_variance_ratio_ * 100

# Print Results
print("PCA Loadings Table (for Supplementary Table S7):")
print(loadings.round(3))
print(f"\nExplained Variance: PC1 = {explained_var[0]:.1f}%, PC2 = {explained_var[1]:.1f}%")
# Out:
# PCA Loadings Table (for Supplementary Table S7):
#       PC1    PC2
# R1  0.339  0.593
# R2  0.345  0.143
# R3  0.338  0.451
# R4  0.360 -0.229
# R5  0.367 -0.228
# R6  0.365  0.082
# GQ  0.366 -0.254
# QG  0.347 -0.499
#
# Explained Variance: PC1 = 89.8%, PC2 = 4.8%

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Sample: Simulated raw topological index data (12 compounds × 8 indices)
np.random.seed(0)
data_raw = pd.DataFrame({
    'R1': np.random.uniform(2.0, 4.0, 12),
    'R2': np.random.uniform(1.0, 3.0, 12),
    'ReZG3': np.random.uniform(1200, 1800, 12),  # High variance
    'R4': np.random.uniform(0.5, 1.5, 12),
    'R5': np.random.uniform(1.5, 2.5, 12),
    'R6': np.random.uniform(0.5, 0.8, 12),
    'GQ': np.random.uniform(3.0, 4.5, 12),
    'QG': np.random.uniform(2.5, 3.5, 12)
})

# Normalize using StandardScaler
scaler = StandardScaler()
data_normalized = pd.DataFrame(scaler.fit_transform(data_raw), columns=data_raw.columns)

# Melt data for plotting
raw_melted = data_raw.melt(var_name='Descriptor', value_name='Value')
norm_melted = data_normalized.melt(var_name='Descriptor', value_name='Value')

# Plot Figure 6 - Raw Distributions
plt.figure(figsize=(12, 6))
sns.violinplot(data=raw_melted, x='Descriptor', y='Value', inner='box', palette='muted')
plt.title('Figure 6. Violin Plots of Raw Topological Indices (Unnormalized)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Figure_6_Raw_Distributions.png", dpi=300)
plt.show()

# Plot Figure 7 - Normalized Distributions
plt.figure(figsize=(12, 6))
sns.violinplot(data=norm_melted, x='Descriptor', y='Value', inner='box', palette='pastel')
plt.title('Figure 7. Violin Plots of Normalized Topological Indices (Standardized)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Figure_7_Normalized_Distributions.png", dpi=300)
plt.show()
# Out:
# /tmp/ipython-input-21-3693722970.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=raw_melted, x='Descriptor', y='Value', inner='box', palette='muted')
# /tmp/ipython-input-21-3693722970.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=norm_melted, x='Descriptor', y='Value', inner='box', palette='pastel')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# 📊 Replace with your actual topological index values for 12 compounds
data_raw = pd.DataFrame({
    'General Randić': [2.5, 2.6, 2.7, 2.8, 2.5, 2.9, 2.4, 2.3, 2.6, 2.7, 2.5, 2.8],
    'General Sum Degree': [3.2, 3.3, 3.4, 3.5, 3.3, 3.6, 3.1, 3.0, 3.3, 3.4, 3.2, 3.5],
    'Redefined Zagreb 3': [1520, 1530, 1510, 1540, 1500, 1550, 1490, 1480, 1515, 1525, 1505, 1535],
    'Root Sum Degree': [1.1, 1.2, 1.3, 1.2, 1.1, 1.3, 1.0, 1.0, 1.2, 1.2, 1.1, 1.3],
    'Inverse Root Sum': [0.85, 0.86, 0.84, 0.87, 0.83, 0.88, 0.82, 0.81, 0.85, 0.86, 0.84, 0.87],
    'Harmonic Root Sum': [1.5, 1.6, 1.4, 1.6, 1.3, 1.7, 1.2, 1.1, 1.5, 1.6, 1.4, 1.6],
    'Geometric Quadratic': [3.8, 3.9, 4.0, 3.9, 3.7, 4.1, 3.6, 3.5, 3.8, 3.9, 3.7, 4.0],
    'Quadratic Geometric': [2.8, 2.9, 2.7, 2.9, 2.6, 3.0, 2.5, 2.4, 2.8, 2.9, 2.7, 3.0]
})

# Normalize the features using StandardScaler
scaler = StandardScaler()
data_normalized = pd.DataFrame(scaler.fit_transform(data_raw), columns=data_raw.columns)

# Reshape the data for seaborn violin plots
raw_melted = data_raw.melt(var_name='Descriptor', value_name='Value')
norm_melted = data_normalized.melt(var_name='Descriptor', value_name='Value')

# 🔍 Figure 6: Raw Distributions
plt.figure(figsize=(12, 6))
sns.violinplot(data=raw_melted, x='Descriptor', y='Value', inner='box', palette='muted')
plt.title('Figure 6. Violin Plots of Raw Topological Indices (Unnormalized)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Figure_6_Raw_Distributions.png", dpi=300)
plt.show()

# 🔍 Figure 7: Normalized Distributions
plt.figure(figsize=(12, 6))
sns.violinplot(data=norm_melted, x='Descriptor', y='Value', inner='box', palette='pastel')
plt.title('Figure 7. Violin Plots of Normalized Topological Indices (Standardized)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Figure_7_Normalized_Distributions.png", dpi=300)
plt.show()
# Out:
# /tmp/ipython-input-22-3932920860.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=raw_melted, x='Descriptor', y='Value', inner='box', palette='muted')
# /tmp/ipython-input-22-3932920860.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=norm_melted, x='Descriptor', y='Value', inner='box', palette='pastel')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Sample data (replace with actual results)
alphas_lasso = [0.001, 0.01, 0.07, 0.1, 1, 10, 100, 1000]
rmse_lasso =  [2.1,   1.9,  1.75, 1.78, 1.85, 2.4, 3.5, 4.2]
r2_lasso =    [0.65,  0.7,  0.76, 0.74, 0.71, 0.60, 0.45, 0.30]

alphas_elastic = alphas_lasso
rmse_elastic =  [2.2, 1.95, 1.79, 1.81, 1.9, 2.2, 2.9, 3.5]
r2_elastic =    [0.63, 0.68, 0.72, 0.71, 0.68, 0.58, 0.50, 0.35]

alphas_ridge = alphas_lasso
rmse_ridge =   [2.05, 1.89, 1.83, 1.85, 1.93, 2.5, 3.2, 4.0]
r2_ridge =     [0.66, 0.71, 0.73, 0.72, 0.69, 0.55, 0.42, 0.25]

def plot_model_performance(alphas, rmse, r2, model_name, optimal_alpha):
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    sns.set(style="whitegrid")

    # RMSE plot
    axes[0].plot(alphas, rmse, marker='o', label='RMSE')
    axes[0].axvline(optimal_alpha, color='r', linestyle='--', label=f'Optimal α = {optimal_alpha}')
    axes[0].set_xscale('log')
    axes[0].set_title(f'{model_name} - RMSE vs. Alpha')
    axes[0].set_xlabel('Alpha (log scale)')
    axes[0].set_ylabel('RMSE')
    axes[0].legend()

    # R2 plot
    axes[1].plot(alphas, r2, marker='o', color='g', label='$R^2$')
    axes[1].axvline(optimal_alpha, color='r', linestyle='--', label=f'Optimal α = {optimal_alpha}')
    axes[1].set_xscale('log')
    axes[1].set_title(f'{model_name} - $R^2$ vs. Alpha')
    axes[1].set_xlabel('Alpha (log scale)')
    axes[1].set_ylabel('$R^2$')
    axes[1].legend()

    plt.tight_layout()
    plt.savefig(f"{model_name.lower()}_alpha_performance.png", dpi=300)
    plt.show()

# Generate individual figures
plot_model_performance(alphas_lasso, rmse_lasso, r2_lasso, "Lasso", 0.07)
plot_model_performance(alphas_elastic, rmse_elastic, r2_elastic, "ElasticNet", 0.10)
plot_model_performance(alphas_ridge, rmse_ridge, r2_ridge, "Ridge", 0.10)
